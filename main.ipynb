# %%
import pandas as pd
import numpy as np
import model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from importlib import reload

# %%
df=pd.read_csv('./Boston.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO  LSTAT  MEDV
# 0     15.3   4.98  24.0
# 1     17.8   9.14  21.6
# 2     17.8   4.03  34.7
# 3     18.7   2.94  33.4
# 4     18.7   5.33  36.2

# %%
X=df.drop(columns=["MEDV"]).to_numpy()
Y=df["MEDV"].to_numpy()
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train,test_size=0.2)

# %%
reload(model)
reg=model.regression(regularization="L2")
reg.Train(x_train,y_train,omega=10,calc_val=1,x_val=x_val,y_val=y_val,epoch=1000,v=1)
# Out:
# +++++ 0 +++++
# Train Loss :  542.2232532897926
# Valid Loss :  608.3159310395264
# ...
# +++++ 1 +++++
# Train Loss :  191.21614474495726
# Valid Loss :  218.52110810070783
# ...
# +++++ 2 +++++
# Train Loss :  190.37889927978088
# Valid Loss :  217.32378781313992
# ...
# +++++ 3 +++++
# Train Loss :  189.36467184619758
# Valid Loss :  216.00751963448374
# ...
# +++++ 4 +++++
# Train Loss :  188.372415810884
# Valid Loss :  214.7196558496362
# ...
# +++++ 5 +++++
# Train Loss :  187.40263818250423
# Valid Loss :  213.46028221340757
# ...
# +++++ 6 +++++
# Train Loss :  186.45472399702004
# Valid Loss :  212.22864571208595
# ...
# +++++ 7 +++++
# Train Loss :  185.52807023488947
# Valid Loss :  211.0240098946723
# ...
# +++++ 8 +++++
# Train Loss :  184.62209143561242
# Valid Loss :  209.84565887406424
# ...
# +++++ 9 +++++
# Train Loss :  183.7362191970403
# Valid Loss :  208.6928967544819
# ...
# +++++ 10 +++++
# Train Loss :  182.86990165814274
# Valid Loss :  207.56504705205387
# ...
# +++++ 11 +++++
# Train Loss :  182.02260299783055
# ...

# %%
fig,ax=plt.subplots(figsize=(15,10))
ax.plot(reg.Loss_history["train"][1:],color="red",label="train")
ax.plot(reg.Loss_history["val"][1:],color="green",label="valid")
ax.set_xlabel("epochs")
ax.set_ylabel("loss")
ax.legend()

# %%
reg.pred(x_test)
# Out:
# array([18.76982188, 17.763298  , 25.31973879, 11.22328754, 14.0968965 ,
#        20.41168123, 17.21937736, 21.9508781 , 21.48277015, 26.37029825,
#        27.04909122, 19.68147269, 20.63679707, 23.73409333, 16.37351265,
#        24.8529811 , 32.77187145, 15.45738543, 18.01228484, 23.2081978 ,
#        13.8630453 , 21.73298456, 18.99274826, 20.50771764, 37.62465988,
#        18.41020712, 22.10847687, 18.79282504, 16.47349796, 20.31471659,
#        20.65693163, 22.01866849, 25.15945503, 16.75432   , 15.36634949,
#        24.2347867 , 17.06800542, 18.23500263, 22.35045369, 21.27815221,
#        23.02768479, 17.58427136, 14.70153407, 26.23274892, 18.31964854,
#        16.64585418, 11.2345892 , 25.00838955, 31.0550974 , 21.43361297,
#        25.15933433, 19.11966982, 26.51778118, 19.95414727, 25.32117607,
#         8.80938586, 17.04103561, 20.89639453, 20.14785007, 19.98460985,
#        18.88302752, 22.08350768, 19.71089023, 20.67345848, 13.66117859,
# ...
